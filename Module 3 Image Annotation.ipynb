# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
img = cv2.imread("Apollo_11_Launch.jpg", cv2.IMREAD_COLOR)
plt.imshow(img)

# %% [markdown]
# ok, le'ts draw an line

# %%
img = cv2.imread("Apollo_11_Launch.jpg", cv2.IMREAD_COLOR)
cv2.line(img, (200, 100), (400, 100), (255, 0, 0), thickness=5, lineType=cv2.FILLED)
plt.imshow(img)

# %% [markdown]
# ok, put an text.

# %%
img = cv2.imread("Apollo_11_Launch.jpg", cv2.IMREAD_COLOR)
cv2.putText(img, "Hello Apolllo", (200, 700), cv2.FONT_HERSHEY_PLAIN, 2.3, (255, 0, 0), 2, cv2.LINE_AA)
plt.imshow(img)
